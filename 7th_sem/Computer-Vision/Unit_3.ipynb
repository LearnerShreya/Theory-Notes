# %% [markdown]
# ## **UNIT 3: Color Image Processing, Wavelets, and Morphological Processing**
#
# **Color Image Processing:**
#
# * Color Models
#
# ---

# %% [markdown]
# ---
#
# # **UNIT 3: Color Image Processing, Wavelets, and Morphological Processing**
#
# ## **Color Image Processing – Color Models**
#
# ---
#
# ## 🔹 **1. Why Color Image Processing?**
#
# When we see the world, we don’t see just black and white — we see colors 🌸🌿☀️.
# Color helps us **differentiate objects, understand scenes, and detect patterns**.
#
# For example:
#
# * A **red traffic light** immediately tells us to stop.
# * A **ripe fruit** looks different from an unripe one because of color.
#
# 👉 That’s why **Color Image Processing** is important:
# It deals with **representing, processing, and analyzing images that have colors**.
#
# ---
#
# ## 🔹 **2. What is a Color Model?**
#
# A **color model (or color space)** is a **mathematical way of representing colors** using numbers.
# Instead of saying “this pixel is pinkish-red,” we represent it with **coordinates/numbers**.
#
# 👉 Think of it like a **language for colors**:
#
# * Just like we represent a location with (x, y) coordinates on a map,
# * We represent a **color pixel** with a set of numbers (R, G, B or C, M, Y, etc.).
#
# Different **color models** exist because **different tasks** need different ways of handling colors.
#
# ---
#
# ## 🔹 **3. RGB Color Model**
#
# The **most common color model**.
#
# * **Definition:** Represents colors as a combination of **Red (R), Green (G), and Blue (B)** light.
# * **Range:** Each value usually from **0–255** (8-bit).
# * **Additive model:** Adding lights of R, G, B together creates colors.
#
# | R   | G   | B   | Color   |
# | --- | --- | --- | ------- |
# | 0   | 0   | 0   | Black   |
# | 255 | 255 | 255 | White   |
# | 255 | 0   | 0   | Red     |
# | 0   | 255 | 0   | Green   |
# | 0   | 0   | 255 | Blue    |
# | 255 | 255 | 0   | Yellow  |
# | 0   | 255 | 255 | Cyan    |
# | 255 | 0   | 255 | Magenta |
#
# 👉 **Why called Additive?**
# Because colors are produced by **adding light**.
#
# * No light = Black
# * Full light = White
#
# 👉 **Uses:** Computer monitors, TV screens, cameras, smartphones.
#
# ---
#
# ## 🔹 **4. CMY and CMYK Color Models**
#
# **CMY (Cyan, Magenta, Yellow):**
#
# * This is a **subtractive model**.
# * Instead of adding light, it **removes light** from white background (like ink on paper).
#
# Formula relation with RGB:
#
# * C = 1 – R
# * M = 1 – G
# * Y = 1 – B
#
# **CMYK Model:**
#
# * Printers usually use CMY but add **K (Black)** because mixing CMY doesn’t give a deep black.
# * K also saves ink.
#
# 👉 **Uses:** Printing, publishing, photography.
#
# ---
#
# ## 🔹 **5. HSI / HSV / HSL Models**
#
# RGB is good for **machines**, but not for **humans**.
# Humans don’t think in terms of numbers like (120, 200, 55).
# We describe colors as:
#
# * “This is a bright red.”
# * “That’s a dull green.”
#
# 👉 That’s why **HSI (Hue, Saturation, Intensity)** and similar models exist.
#
# * **Hue (H):** The actual color (red, blue, green, etc.).
# * **Saturation (S):** How pure or intense the color is.
#
#   * High S = bright, pure color
#   * Low S = faded, grayish color
# * **Intensity (I):** Brightness (light vs dark).
#
# Variations:
#
# * **HSV:** Hue, Saturation, Value
# * **HSL:** Hue, Saturation, Lightness
#
# 👉 **Uses:**
#
# * Image segmentation (separating objects by color).
# * Face detection, object tracking.
# * Photoshop and editing software color pickers.
#
# ---
#
# ## 🔹 **6. YCbCr Model**
#
# * Separates brightness (Y) from color information (Cb, Cr).
#
# - **Y = Luminance** (brightness, black-and-white part).
# - **Cb = Blue difference chroma**.
# - **Cr = Red difference chroma**.
#
# 👉 Why useful?
#
# * Human eyes are more sensitive to brightness than to fine color details.
# * So we can **store/transmit Y in high quality, and compress Cb, Cr** to save space.
#
# 👉 **Uses:** JPEG images, MPEG videos, TV broadcasting.
#
# ---
#
# ## 🔹 **7. CIE Models**
#
# These are **device-independent** models.
# Unlike RGB (device-specific: monitor, camera) or CMYK (printer-specific), CIE models give a **universal representation of color**.
#
# ### (a) CIE XYZ
#
# * Any visible color can be represented as a mix of 3 values (X, Y, Z).
# * Foundation of modern color science.
#
# ### (b) CIE $L*a*b* (Lab)$
#
# * **L** = Lightness
# * **a** = Green ↔ Red axis
# * **b** = Blue ↔ Yellow axis
# * Designed so that **numerical difference = actual visual difference**.
#
# 👉 **Uses:**
#
# * Image color correction
# * Machine vision
# * Industrial applications where exact color matching is required
#
# ---
#
# ## 📊 **Comparison Table of Color Models**
#
# | Model           | Type               | Components                 | Idea                        | Applications              |
# | --------------- | ------------------ | -------------------------- | --------------------------- | ------------------------- |
# | **RGB**         | Additive           | R, G, B                    | Combine lights              | Displays, Cameras         |
# | **CMY/CMYK**    | Subtractive        | C, M, Y, K                 | Absorb/reflection           | Printing, Publishing      |
# | **HSI/HSV/HSL** | Perceptual         | Hue, Saturation, Intensity | Human-like description      | Vision, Editing           |
# | **YCbCr**       | Luminance-Chroma   | Y, Cb, Cr                  | Separate brightness & color | Compression (JPEG, Video) |
# | **CIE XYZ/Lab** | Device-independent | X, Y, Z / L, a, b          | Standard universal system   | Color correction, Vision  |
#
# ---
#
# ## ✅ **Quick Recap (Memory Friendly)**
#
# * **RGB** → Additive, screen display.
# * **CMYK** → Subtractive, printing.
# * **HSI/HSV/HSL** → Human-like, object detection, editing.
# * **YCbCr** → Compression, broadcasting.
# * **CIE Lab** → Device-independent, accurate color representation.
#
# ---

# %% [markdown]
# ---
#
# # **CIE L\*a\*b\* (Lab) Color Model**
#
# ---
#
# ## 🔹 1. What is it?
#
# The **CIE L\*a\*b\*** (or just Lab) is a **color model developed by the International Commission on Illumination (CIE)**.
# It is designed to be:
#
# * **Device-independent** → meaning the same color looks the same on different devices (monitor, printer, camera).
# * **Perceptually uniform** → numerical differences in Lab values match how humans actually see differences in color.
#
# 👉 That makes it very useful in **color correction, machine vision, and industry** where accurate color matching is needed.
#
# ---
#
# ## 🔹 2. Components of Lab Model
#
# The Lab model has **three components**:
#
# 1. **L\*** = **Lightness** (how light or dark a color is)
#
#    * Scale: 0 = black, 100 = white
#
# 2. **a\*** = **Green ↔ Red axis**
#
#    * Negative values = green
#    * Positive values = red
#
# 3. **b\*** = **Blue ↔ Yellow axis**
#
#    * Negative values = blue
#    * Positive values = yellow
#
# 👉 Together, any visible color can be represented by these three numbers: (L\*, a\*, b\*).
#
# ---
#
# ## 🔹 3. Why is it special?
#
# Unlike RGB or CMYK (which depend on device properties), **Lab is based on human vision**.
#
# * If two colors differ by "10 units" in Lab space, the difference looks equally big to human eyes — this is called **perceptual uniformity**.
# * It’s also **larger** than RGB or CMYK, meaning it can represent more colors (the full range visible to humans).
#
# ---
#
# ## 🔹 4. Example
#
# Let’s say:
#
# * (L=50, a=+40, b=+20) → A medium red color.
# * (L=50, a=-40, b=+20) → Same brightness, but greenish-yellow.
#
# Notice how **a changes direction** (red vs green) while L and b stay the same.
#
# ---
#
# ## 🔹 5. Applications
#
# 1. **Image editing** → Photoshop often uses Lab mode for advanced color correction.
# 2. **Printing industry** → Ensures the printed color matches the digital design.
# 3. **Machine vision** → Object recognition, defect detection.
# 4. **Color difference measurement** → Used in quality control (e.g., making sure all product batches have the same shade).
#
# ---
#
# ✅ **In short:**
# The **CIE L\*a\*b\*** model represents color in a way that is **closer to human perception** than RGB or CMYK, and is **device-independent**, making it very useful for accurate color work.
#
# ---
