# %% [markdown]
# # Big Data Implementation Tasks
#
# 1. Installing Cloudera on Windows using VirtualBox involves setting up a virtual machine (VM).
#
# 2. Implement the following file management tasks in Hadoop:
#    - Adding files and directories
#    - Retrieving files from HDFS to local filesystem
#    - Deleting Files from HDFS
#
# 3. To Run a Java program based on parallel programming to implement the concept of Map Reduce Paradigm.
#
# 4. Implement the following file management tasks in Sqoop over Hadoop:
#    - Create a Database
#    - Create Table
#    - Insert Some Records
#
# 5. Install and Run Hive, then use Hive to Create, alter and drop databases, tables, views, functions, and Indexes.
#
# 6. Write a program to analyze the Web server log stream data using Apache Flume Framework.
#
# 7. Implement the following file management tasks of HBase NoSQL over Hadoop:
#    - Operating on Table
#    - Insert Some Records
#    - Display Table Data
#
# 8. Implement the following file management tasks in Spark over Hadoop environment:
#    - RDD using in-memory dataset
#    - RDD using file
#    - Using Map Function
#    - Using Reduce Function
#    - Word Count (flatMap)
#
# 9. To install and run Pig. Write Pig Latin scripts to sort, group, join, project, and filter data.

# %% [markdown]
# List of Experiments:
# 1. Hands-on with Map Reduce: Hadoop, Hive, MapR
# 2. Hands-on with NoSQL Databases: S3, Hadoop Distributed File System(HDFS)
# 3. Hands-on with Statistical Packages
# 4. Hands-on with Visual Data Analysis tools

# %% [markdown]
# # Big Data Implementation Tasks
#
# 1. Installing Cloudera on Windows using VirtualBox
# Setting up a virtual machine (VM) to install and run Cloudera on Windows using VirtualBox.
#
# 2. Hadoop File Management Tasks
# - Adding files and directories
# - Retrieving files from HDFS to the local filesystem
# - Deleting files from HDFS
#
# 3. Implementing MapReduce in Java
# Run a Java program using parallel programming to implement the concept of the MapReduce paradigm.
#
# 4. Sqoop File Management Tasks Over Hadoop
# - Create a Database
# - Create a Table
# - Insert Some Records
#
# 5. Installing and Running Hive
# Use Hive to perform the following operations:
# - Create, alter, and drop databases
# - Create, alter, and drop tables, views, functions, and indexes
#
# 6. Web Server Log Analysis Using Apache Flume
# Write a program to analyze web server log stream data using the Apache Flume framework.
#
# 7. HBase File Management Tasks Over Hadoop (NoSQL)
# - Operating on tables
# - Inserting records
# - Displaying table data
#
# 8. Spark File Management Tasks Over Hadoop
# - RDD using in-memory dataset
# - RDD using file
# - Using Map function
# - Using Reduce function
# - Word Count using `flatMap`
#
# 9. Installing and Running Pig
# Write Pig Latin scripts to:
# - Sort data
# - Group data
# - Join data
# - Project data
# - Filter data
